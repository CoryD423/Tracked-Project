# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting category_encoders==2.6.1
#   Downloading category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 KB 10.6 MB/s eta 0:00:00
# Collecting imblearn==0.0
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting xgboost==1.7.6
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 8.6 MB/s eta 0:00:00
# Collecting hyperopt==0.2.7
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.6 MB/s eta 0:00:00
# Collecting shap==0.41.0
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 KB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 6)) (22.0.4)
# Collecting prophet==1.1.4
#   Downloading prophet-1.1.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from category_encoders==2.6.1->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: scipy>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from category_encoders==2.6.1->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from category_encoders==2.6.1->-r ./requirements.txt (line 1)) (1.1.2)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 26.8 MB/s eta 0:00:00
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 68.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from category_encoders==2.6.1->-r ./requirements.txt (line 1)) (1.2.5)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 KB 34.1 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /shared-libs/python3.9/py/lib/python3.9/site-packages (from hyperopt==0.2.7->-r ./requirements.txt (line 4)) (0.18.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from hyperopt==0.2.7->-r ./requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from hyperopt==0.2.7->-r ./requirements.txt (line 4)) (4.64.1)
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 KB 29.2 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>20.9 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from shap==0.41.0->-r ./requirements.txt (line 5)) (21.3)
# Collecting numba
#   Downloading numba-0.57.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 41.3 MB/s eta 0:00:00
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prophet==1.1.4->-r ./requirements.txt (line 7)) (2.8.2)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 KB 7.4 MB/s eta 0:00:00
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 KB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from prophet==1.1.4->-r ./requirements.txt (line 7)) (3.6.0)
# Collecting importlib-resources
#   Downloading importlib_resources-6.0.0-py3-none-any.whl (31 kB)
# Collecting holidays>=0.25
#   Downloading holidays-0.28-py3-none-any.whl (642 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.9/642.9 KB 45.9 MB/s eta 0:00:00
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 49.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pytz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from LunarCalendar>=0.0.9->prophet==1.1.4->-r ./requirements.txt (line 7)) (2022.5)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet==1.1.4->-r ./requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet==1.1.4->-r ./requirements.txt (line 7)) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet==1.1.4->-r ./requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet==1.1.4->-r ./requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet==1.1.4->-r ./requirements.txt (line 7)) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet==1.1.4->-r ./requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.20.0->category_encoders==2.6.1->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.20.0->category_encoders==2.6.1->-r ./requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-resources->prophet==1.1.4->-r ./requirements.txt (line 7)) (3.9.0)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 17.1 MB/s eta 0:00:00
# Building wheels for collected packages: pymeeus
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732017 sha256=86425ed3bef448cbfd6f8b18ac73a195b11cd805ba93339d2a53a630d973e9fa
#   Stored in directory: /root/.cache/pip/wheels/04/1f/e5/8dd0c661cd8d252817655dc14a84f7ae045d6616594145aa81
# Successfully built pymeeus
# Installing collected packages: pymeeus, py4j, ephem, slicer, patsy, networkx, llvmlite, importlib-resources, convertdate, cloudpickle, xgboost, numba, LunarCalendar, hyperopt, holidays, statsmodels, shap, imbalanced-learn, cmdstanpy, prophet, imblearn, category_encoders
# Successfully installed LunarCalendar-0.0.9 category_encoders-2.6.1 cloudpickle-2.2.1 cmdstanpy-1.1.0 convertdate-2.4.0 ephem-4.1.4 holidays-0.28 hyperopt-0.2.7 imbalanced-learn-0.11.0 imblearn-0.0 importlib-resources-6.0.0 llvmlite-0.40.1 networkx-3.1 numba-0.57.1 patsy-0.5.3 prophet-1.1.4 py4j-0.10.9.7 pymeeus-0.5.12 shap-0.41.0 slicer-0.0.7 statsmodels-0.14.0 xgboost-1.7.6
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=39ff504f-0c4f-4bcb-9b0d-eb99ef4b289f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
